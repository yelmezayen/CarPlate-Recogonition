# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import cv2

# %%
# Load the CSV file into a DataFrame
csv_path = r'C:\Users\Mostafa\Desktop\Project_Files\1_Labeling\annotations.csv'
df = pd.read_csv(csv_path)

# Display the first few rows of the DataFrame
df.head()
# Out:
#                                             filepath  xmin  xmax  ymin  ymax
# 0  C:\Users\Mostafa\Desktop\Project_Files\1_Label...  1099  1402   647   729
# 1  C:\Users\Mostafa\Desktop\Project_Files\1_Label...   131   302   307   350
# 2  C:\Users\Mostafa\Desktop\Project_Files\1_Label...    22   139   129   163
# 3  C:\Users\Mostafa\Desktop\Project_Files\1_Label...   163   316   209   250
# 4  C:\Users\Mostafa\Desktop\Project_Files\1_Label...   810  1067   677   727

# %%
import xml.etree.ElementTree as xet

# %%
filename = df['filepath'][0]
filename
# Out:
# 'C:\\Users\\Mostafa\\Desktop\\Project_Files\\1_Labeling\\images\\N1.xml'

# %%
import os
import xml.etree.ElementTree as ET

# Load the CSV file into a DataFrame
csv_path = r'C:\Users\Mostafa\Desktop\Project_Files\1_Labeling\annotations.csv'
df = pd.read_csv(csv_path)

# Define the directory where the XML files are located
xml_dir = r'C:\Users\Mostafa\Desktop\Project_Files\1_Labeling\images'

# Get the first filename from the 'filepath' column and construct the full path
filename = df['filepath'][0]
full_filename = filename
print(f"Full path to the XML file: {full_filename}")

# Define the function to get the image file path from the XML file
def getFilename(filename):
    try:
        # Parse the XML file
        tree = ET.parse(filename)
        root = tree.getroot()
        # Find the 'filename' tag and extract its text
        filename_image = root.find('filename').text
        # Construct the full file path
        filepath_image = os.path.join(xml_dir, filename_image)
        return filepath_image
    except Exception as e:
        print(f"Error processing file {filename}: {e}")
        return None

# Call the function with the constructed full path
result = getFilename(full_filename)
if result:
    print(f"Constructed image file path: {result}")
else:
    print("Failed to construct image file path.")
# Out:
# Full path to the XML file: C:\Users\Mostafa\Desktop\Project_Files\1_Labeling\images\N1.xml
# Constructed image file path: C:\Users\Mostafa\Desktop\Project_Files\1_Labeling\images\N1.jpeg

# %%
image_path = list(df['filepath'].apply(getFilename))
image_path
# Out:
# ['C:\\Users\\Mostafa\\Desktop\\Project_Files\\1_Labeling\\images\\N1.jpeg',
#  'C:\\Users\\Mostafa\\Desktop\\Project_Files\\1_Labeling\\images\\N100.jpeg',
#  'C:\\Users\\Mostafa\\Desktop\\Project_Files\\1_Labeling\\images\\N101.jpeg',
#  'C:\\Users\\Mostafa\\Desktop\\Project_Files\\1_Labeling\\images\\N102.jpeg',
#  'C:\\Users\\Mostafa\\Desktop\\Project_Files\\1_Labeling\\images\\N103.jpeg',
#  'C:\\Users\\Mostafa\\Desktop\\Project_Files\\1_Labeling\\images\\N104.jpeg',
#  'C:\\Users\\Mostafa\\Desktop\\Project_Files\\1_Labeling\\images\\N105.jpeg',
#  'C:\\Users\\Mostafa\\Desktop\\Project_Files\\1_Labeling\\images\\N106.jpeg',
#  'C:\\Users\\Mostafa\\Desktop\\Project_Files\\1_Labeling\\images\\N107.jpeg',
#  'C:\\Users\\Mostafa\\Desktop\\Project_Files\\1_Labeling\\images\\N108.jpeg',
#  'C:\\Users\\Mostafa\\Desktop\\Project_Files\\1_Labeling\\images\\N109.jpeg',
#  'C:\\Users\\Mostafa\\Desktop\\Project_Files\\1_Labeling\\images\\N11.jpeg',
# ...

# %%
file_path = image_path[0]
file_path
# Out:
# 'C:\\Users\\Mostafa\\Desktop\\Project_Files\\1_Labeling\\images\\N1.jpeg'

# %%
img = cv2.imread(file_path)

cv2.namedWindow('example',cv2.WINDOW_NORMAL)
cv2.imshow('example',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# 1093	1396	645	727
cv2.rectangle(img,(1093,645),(1396,727),(0,255,0),3)
cv2.namedWindow('example',cv2.WINDOW_NORMAL)
cv2.imshow('example',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
labels = df.iloc[:,1:].values 
labels
# Out:
# array([[1099, 1402,  647,  729],
#        [ 131,  302,  307,  350],
#        [  22,  139,  129,  163],
#        [ 163,  316,  209,  250],
#        [ 810, 1067,  677,  727],
#        [  64,  158,  163,  196],
#        [ 361,  435,  174,  195],
#        [ 127,  267,  249,  293],
#        [ 198,  350,  165,  293],
#        [ 185,  341,  212,  251],
#        [  97,  241,  240,  321],
#        [ 127,  192,  127,  145],
#        [ 185,  248,  207,  234],
#        [  65,  240,  358,  412],
#        [ 173,  352,  261,  292],
#        [  39,  109,  129,  161],
#        [  18,  198,   32,  133],
#        [ 158,  310,  230,  278],
#        [ 120,  245,  164,  200],
#        [ 501,  850,  632,  719],
#        [ 176,  559,  214,  321],
#        [ 964, 1295,  663,  767],
#        [ 646,  735,  332,  390],
#        [ 311,  507,  323,  373],
#        [ 342,  494,  246,  288],
#        [   9,  250,   89,  171],
#        [ 168,  327,  282,  325],
#        [ 124,  403,  268,  337],
# ...

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from os.path import exists

labels = df.iloc[:,1:].values
data= []
output= []
for ind in range(len(image_path)):
    image = image_path[ind]
    print("path of the image", image)
    file_exists = exists(image)
    if file_exists:
        print('File Exists in the path')
    else:
        print('file doesnot exists in the path')


    img_arr = cv2.imread(image)
    h,w,d = img_arr.shape
    # prepprocesing
    load_image = load_img(image,target_size=(224,224))
    load_image_arr = img_to_array(load_image)
    norm_load_image_arr = load_image_arr/255.0 # normalization
    # normalization to labels
    xmin,xmax,ymin,ymax = labels[ind]
    nxmin,nxmax = xmin/w,xmax/w
    nymin,nymax = ymin/h,ymax/h
    label_norm = (nxmin,nxmax,nymin,nymax) # normalized output
    # -------------- append
    data.append(norm_load_image_arr)
    output.append(label_norm)
# Out:
# path of the image C:\Users\Mostafa\Desktop\Project_Files\1_Labeling\images\N1.jpeg
# File Exists in the path
# path of the image C:\Users\Mostafa\Desktop\Project_Files\1_Labeling\images\N100.jpeg
# File Exists in the path
# path of the image C:\Users\Mostafa\Desktop\Project_Files\1_Labeling\images\N101.jpeg
# File Exists in the path
# path of the image C:\Users\Mostafa\Desktop\Project_Files\1_Labeling\images\N102.jpeg
# File Exists in the path
# path of the image C:\Users\Mostafa\Desktop\Project_Files\1_Labeling\images\N103.jpeg
# File Exists in the path
# path of the image C:\Users\Mostafa\Desktop\Project_Files\1_Labeling\images\N104.jpeg
# File Exists in the path
# path of the image C:\Users\Mostafa\Desktop\Project_Files\1_Labeling\images\N105.jpeg
# File Exists in the path
# path of the image C:\Users\Mostafa\Desktop\Project_Files\1_Labeling\images\N106.jpeg
# File Exists in the path
# path of the image C:\Users\Mostafa\Desktop\Project_Files\1_Labeling\images\N107.jpeg
# ...

# %%
X = np.array(data,dtype=np.float32)
y = np.array(output,dtype=np.float32)

# %%
X.shape,y.shape
# Out:
# ((228, 224, 224, 3), (228, 4))

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,train_size=0.8,random_state=0)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((182, 224, 224, 3), (46, 224, 224, 3), (182, 4), (46, 4))

# %%
from tensorflow.keras.applications import MobileNetV2, InceptionV3, InceptionResNetV2
from tensorflow.keras.layers import Dense, Dropout, Flatten, Input
from tensorflow.keras.models import Model
import tensorflow as tf

# %%
inception_resnet = InceptionV3(weights="imagenet",include_top=False,input_tensor=Input(shape=(224,224,3)))
inception_resnet.trainable=False
# ---------------------
headmodel = inception_resnet.output
headmodel = Flatten()(headmodel)
# headmodel = Dense(500,activation="relu")(headmodel)
headmodel = Dense(64,activation="relu")(headmodel)
headmodel = Dense(4,activation='sigmoid')(headmodel)
# ---------- model
model = Model(inputs=inception_resnet.input,outputs=headmodel)
# complie model
model.compile(loss='mean_squared_error',optimizer=tf.keras.optimizers.Adam(learning_rate=1e-6))
model.summary()
# Out:
# ...
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 12s 0us/step
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)    │ (None, 224, 224, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_406 (Conv2D)           │ (None, 111, 111, 32)      │             864 │ input_layer_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_406       │ (None, 111, 111, 32)      │              96 │ conv2d_406[0][0]           │
# ...

# %%
from tensorflow.keras.callbacks import TensorBoard

# %%
tfb = TensorBoard('object_detection')

# %%
history = model.fit(x=x_train,y=y_train,batch_size=10,epochs=100,
                    validation_data=(x_test,y_test),callbacks=[tfb])
# Out:
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 315ms/step - loss: 0.0947 - val_loss: 0.0677
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 197ms/step - loss: 0.0579 - val_loss: 0.0498
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 198ms/step - loss: 0.0478 - val_loss: 0.0464
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 0.0408 - val_loss: 0.0453
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 197ms/step - loss: 0.0364 - val_loss: 0.0435
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 0.0329 - val_loss: 0.0419
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 198ms/step - loss: 0.0328 - val_loss: 0.0410
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 197ms/step - loss: 0.0303 - val_loss: 0.0397
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 204ms/step - loss: 0.0286 - val_loss: 0.0390
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 208ms/step - loss: 0.0283 - val_loss: 0.0381
# Epoch 11/100
# ...

# %%
model_save_path = r"C:\Users\Mostafa\Desktop\Project_Files\1_Labeling\objectDetectionModel.h5"
model.save(model_save_path)
print('Model saved successfully')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully
